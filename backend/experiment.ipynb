# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# db.py
import boto3

session = boto3.Session()
creds = session.get_credentials()
print("Access key:", creds.access_key)
print("Has token:", creds.token is not None)
print("Region:", session.region_name)
# Out:
# Access key: AKIA243NF7PSUVVEQOHD
# Has token: False
# Region: us-west-2

# %%
dynamodb = boto3.resource(
    "dynamodb",
    region_name="us-west-2"
)

table = dynamodb.Table("audio-books")
table
# Out:
# dynamodb.Table(name='audio-books')

# %%
item = {
    "user_id": "pending",
}

table.put_item(Item=item)
# Out:
# {'ResponseMetadata': {'RequestId': 'MNHOKS773LHAKI3IAB66BL5AOVVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sat, 18 Apr 2026 15:52:47 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'MNHOKS773LHAKI3IAB66BL5AOVVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}
